# %%
import pandas as pd
import mysql.connector as mysql

conn = mysql.connect(host='localhost', database='laravel_test', user='root', password='root')
cursor = conn.cursor()
#obtaining records
q1="SELECT * FROM posts where post_id" #just for testing
cursor.execute(q1)
result = cursor.fetchall()
result
# Out:
# c:\anaconda\envs\machine_learning\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# c:\anaconda\envs\machine_learning\lib\site-packages\numpy\.libs\libopenblas.GK7GX5KEQ4F6UYO3P26ULGBQYHGQO7J4.gfortran-win_amd64.dll
# c:\anaconda\envs\machine_learning\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"
# [(1,
#   'ارتفاع التضخم بالكويت 3.19 في المئة في سبتمبر  ',
#   24,
#   'https://www.barqnewskw.com/news/show/%D8%A7%D8%B1%D8%AA%D9%81%D8%A7%D8%B9_%D8%A7%D9%84%D8%AA%D8%B6%D8%AE%D9%85_%D8%A8%D8%A7%D9%84%D9%83%D9%88%D9%8A%D8%AA_3.19_%D9%81%D9%8A_%D8%A7%D9%84%D9%85%D8%A6%D8%A9_%D9%81%D9%8A_%D8%B3%D8%A8%D8%AA%D9%85%D8%A8%D8%B1__',
#   4,
#   'https://www.barqnewskw.com//assets/uplaods/1667315974.jpeg',
# ...

# %%
q2="SELECT COLUMN_NAME FROM INFORMATION_SCHEMA.COLUMNS WHERE TABLE_NAME = 'posts' ORDER BY ORDINAL_POSITION;"
cursor.execute(q2)
col_names = cursor.fetchall()
fin_col_names=[]
for tup in col_names:
    fin_col_names.append(tup[0])
fin_col_names
# Out:
# ['post_id',
#  'title',
#  'agency_id',
#  'post_url',
#  'category_id',
#  'image_url',
#  'contents',
#  'published_date_and_time',
#  'author_name',
#  'main_category_id',
#  'sub_category_id',
#  'media_type',
#  'slug',
#  'urgency',
#  'source_id',
#  'status',
#  'created_at',
#  'updated_at',
#  'deleted_at',
#  'tweet_created_at',
#  'tweet_text',
#  'tweet_id',
#  'vdo_title',
#  'vdo_description',
#  'vdo_published_at',
#  'vdo_thumbnail',
#  'vdo_url',
#  'active_id',
#  'trending_count']

# %%
len(fin_col_names)
# Out:
# 29

# %%
fin_col_names,len(fin_col_names)
# Out:
# (['post_id',
#   'title',
#   'agency_id',
#   'post_url',
#   'category_id',
#   'image_url',
#   'contents',
#   'published_date_and_time',
#   'author_name',
#   'main_category_id',
#   'sub_category_id',
#   'media_type',
#   'slug',
#   'urgency',
#   'source_id',
#   'status',
#   'created_at',
#   'updated_at',
#   'deleted_at',
#   'tweet_created_at',
#   'tweet_text',
#   'tweet_id',
#   'vdo_title',
#   'vdo_description',
#   'vdo_published_at',
#   'vdo_thumbnail',
#   'vdo_url',
#   'active_id',
#   'trending_count'],
#  29)

# %%
ser_col_list=['post_id', 'post_id', 'title', 'title', 
'agency_id', 'agency_id', 'post_url', 'post_url', 
'category_id', 'category_id', 'image_url', 'image_url', 
'contents', 'contents', 'published_date_and_time', 
'published_date_and_time', 'author_name', 'author_name', 
'main_category_id', 'main_category_id', 'sub_category_id', 'sub_category_id', 'media_type', 'media_type', 'slug', 'slug', 'urgency', 'urgency', 'source_id', 'source_id', 'status', 'status', 'created_at', 'created_at', 'updated_at', 'updated_at', 'deleted_at', 'deleted_at', 'tweet_created_at', 'tweet_created_at', 'tweet_text', 'tweet_text', 'tweet_id', 'tweet_id', 'vdo_title', 'vdo_title', 'vdo_description', 'vdo_description', 'vdo_published_at', 'vdo_published_at', 'vdo_thumbnail', 'vdo_thumbnail', 'vdo_url', 'vdo_url', 'active_id',
 'active_id', 'trending_count', 'trending_count'] 
len(ser_col_list)
# Out:
# 58

# %%
df=pd.DataFrame(result)
df.columns=fin_col_names
df
# Out:
#      post_id                                              title  agency_id  \
# 0          1    ارتفاع التضخم بالكويت 3.19 في المئة في سبتمبر           24
# 1          2  30.9 مليار دينار عمليات البطاقات المصرفية في 9...         24
# 2          3  بورصة مصر تقفز لأعلى مستوى في 6 أشهر مع إعلان ...         24
# 3          4  «النفط» استعرضت في «أديبك» استخدام الكويت لأحد...         24
# 4          5  «الشال»: «بيع الإجازات» و«الأمامية» حراج لتسري...         24
# ..       ...                                                ...        ...
# 119      120  قوة الإطفاء: التعامل مع 147 حادث خلال فترة هطو...          8
# 120      121  مراكز اقتراع الانتخابات النيابية والبلدية في ا...          8
# 121      122  ترامب يقاضي لجنة التحقيق في الهجوم على الكونغر...          8
# 122      123  ترامب يعلن الثلاثاء ترشحه لخوض الانتخابات الرئ...          8
# 123      124  #النيابة_العامة تأمر بحجز عضو في #المجلس_البلد...          9
#
# ...

# %%
# from torch import embedding


class hubs():
    def train(self,txt):
        return txt
    def load(self,url):
        return self.train

hub=hubs()
model=hub.load("www.com")
model("hey")
# Out:
# str
